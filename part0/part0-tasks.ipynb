# %% [markdown]
# ### Import to allow usage of mermaid inside jupyter notebook

# %%
import base64
from IPython.display import Image, display

def mm(graph):
    graphbytes = graph.encode("utf8")
    base64_bytes = base64.urlsafe_b64encode(graphbytes)
    base64_string = base64_bytes.decode("ascii")
    display(Image(url="https://mermaid.ink/img/" + base64_string))

# %% [markdown]
# ### 0.4: New note diagram

# %% [markdown]
# The first step when submitting a new note, is an HTTP POST request to the server address new_note. The server responds with HTTP status code 302. This is a url redirect, which the server asks the browser to preform an new HTTP Get as the second step to the address defined in the header's location.
#
# After which it will reload the notes page, causing three more HTTP requests:
# fetching the style sheet, the JavaScript code (main.js) and the raw data of the notes (data.js)

# %%
mm("""
sequenceDiagram
    participant browser
    participant server

    browser->>server: POST https://studies.cs.helsinki.fi/exampleapp/new_note
    activate server
    server-->>browser: URL Redirect 
    deactivate server

    browser->>server: GET https://studies.cs.helsinki.fi/exampleapp/notes
    activate server
    server-->>browser: HTML document
    deactivate server

    browser->>server: GET https://studies.cs.helsinki.fi/exampleapp/main.css
    activate server
    server-->>browser: Returns the css file
    deactivate server
   
    browser->>server: GET https://studies.cs.helsinki.fi/exampleapp/main.js
    activate server
    server-->>browser: Returns the JavaScript file
    deactivate server

    Note right of browser: The browser starts executing the JavaScript code that fetches the JSON from the server

    browser->>server: GET https://studies.cs.helsinki.fi/exampleapp/data.json
    activate server
    server-->>browser: [{ "content": "HTML is easy", "date": "2023-1-1" }, ... ]
    deactivate server

    Note right of browser: The browser executes the callback function that renders the notes
""")
# Out:
# <img src="https://mermaid.ink/img/CnNlcXVlbmNlRGlhZ3JhbQogICAgcGFydGljaXBhbnQgYnJvd3NlcgogICAgcGFydGljaXBhbnQgc2VydmVyCgogICAgYnJvd3Nlci0-PnNlcnZlcjogUE9TVCBodHRwczovL3N0dWRpZXMuY3MuaGVsc2lua2kuZmkvZXhhbXBsZWFwcC9uZXdfbm90ZQogICAgYWN0aXZhdGUgc2VydmVyCiAgICBzZXJ2ZXItLT4-YnJvd3NlcjogVVJMIFJlZGlyZWN0IAogICAgZGVhY3RpdmF0ZSBzZXJ2ZXIKCiAgICBicm93c2VyLT4-c2VydmVyOiBHRVQgaHR0cHM6Ly9zdHVkaWVzLmNzLmhlbHNpbmtpLmZpL2V4YW1wbGVhcHAvbm90ZXMKICAgIGFjdGl2YXRlIHNlcnZlcgogICAgc2VydmVyLS0-PmJyb3dzZXI6IEhUTUwgZG9jdW1lbnQKICAgIGRlYWN0aXZhdGUgc2VydmVyCgogICAgYnJvd3Nlci0-PnNlcnZlcjogR0VUIGh0dHBzOi8vc3R1ZGllcy5jcy5oZWxzaW5raS5maS9leGFtcGxlYXBwL21haW4uY3NzCiAgICBhY3RpdmF0ZSBzZXJ2ZXIKICAgIHNlcnZlci0tPj5icm93c2VyOiBSZXR1cm5zIHRoZSBjc3MgZmlsZQogICAgZGVhY3RpdmF0ZSBzZXJ2ZXIKCiAgICBicm93c2VyLT4-c2VydmVyOiBHRVQgaHR0cHM6Ly9zdHVkaWVzLmNzLmhlbHNpbmtpLmZpL2V4YW1wbGVhcHAvbWFpbi5qcwogICAgYWN0aXZhdGUgc2VydmVyCiAgICBzZXJ2ZXItLT4-YnJvd3NlcjogUmV0dXJucyB0aGUgSmF2YVNjcmlwdCBmaWxlCiAgICBkZWFjdGl2YXRlIHNlcnZlcgoKICAgIE5vdGUgcmln
# ...

# %% [markdown]
# ### 0.5: Single page app diagram

# %%
mm("""
sequenceDiagram
    participant browser
    participant server

    browser->>server: GET https://studies.cs.helsinki.fi/exampleapp/spa
    activate server
    server-->>browser: HTML document
    deactivate server

    browser->>server: GET https://studies.cs.helsinki.fi/exampleapp/main.css
    activate server
    server-->>browser: Returns the css file
    deactivate server
   
    browser->>server: GET https://studies.cs.helsinki.fi/exampleapp/spa.js
    activate server
    server-->>browser: Returns the JavaScript file
    deactivate server

    Note right of browser: The browser starts executing the JavaScript code that fetches the JSON from the server

    browser->>server: GET https://studies.cs.helsinki.fi/exampleapp/data.json
    activate server
    server-->>browser: [{ "content": "HTML is easy", "date": "2023-1-1" }, ... ]
    deactivate server

    Note right of browser: The browser executes the callback function that renders the notes
""")
# Out:
# <img src="https://mermaid.ink/img/CnNlcXVlbmNlRGlhZ3JhbQogICAgcGFydGljaXBhbnQgYnJvd3NlcgogICAgcGFydGljaXBhbnQgc2VydmVyCgogICAgYnJvd3Nlci0-PnNlcnZlcjogR0VUIGh0dHBzOi8vc3R1ZGllcy5jcy5oZWxzaW5raS5maS9leGFtcGxlYXBwL3NwYQogICAgYWN0aXZhdGUgc2VydmVyCiAgICBzZXJ2ZXItLT4-YnJvd3NlcjogSFRNTCBkb2N1bWVudAogICAgZGVhY3RpdmF0ZSBzZXJ2ZXIKCiAgICBicm93c2VyLT4-c2VydmVyOiBHRVQgaHR0cHM6Ly9zdHVkaWVzLmNzLmhlbHNpbmtpLmZpL2V4YW1wbGVhcHAvbWFpbi5jc3MKICAgIGFjdGl2YXRlIHNlcnZlcgogICAgc2VydmVyLS0-PmJyb3dzZXI6IFJldHVybnMgdGhlIGNzcyBmaWxlCiAgICBkZWFjdGl2YXRlIHNlcnZlcgoKICAgIGJyb3dzZXItPj5zZXJ2ZXI6IEdFVCBodHRwczovL3N0dWRpZXMuY3MuaGVsc2lua2kuZmkvZXhhbXBsZWFwcC9zcGEuanMKICAgIGFjdGl2YXRlIHNlcnZlcgogICAgc2VydmVyLS0-PmJyb3dzZXI6IFJldHVybnMgdGhlIEphdmFTY3JpcHQgZmlsZQogICAgZGVhY3RpdmF0ZSBzZXJ2ZXIKCiAgICBOb3RlIHJpZ2h0IG9mIGJyb3dzZXI6IFRoZSBicm93c2VyIHN0YXJ0cyBleGVjdXRpbmcgdGhlIEphdmFTY3JpcHQgY29kZSB0aGF0IGZldGNoZXMgdGhlIEpTT04gZnJvbSB0aGUgc2VydmVyCgogICAgYnJvd3Nlci0-PnNlcnZlcjogR0VUIGh0dHBzOi8vc3R1ZGllcy5jcy5oZWxzaW5raS5maS9l
# ...

# %% [markdown]
# ### 0.6: Single page new note diagram

# %%
mm("""
sequenceDiagram
    participant browser
    participant server

    browser->>server: POST https://studies.cs.helsinki.fi/exampleapp/new_note_spa
    activate server
    server-->>browser: JSON response
    deactivate server

    Note right of browser: There is no need to refetch the HTML document
""")
